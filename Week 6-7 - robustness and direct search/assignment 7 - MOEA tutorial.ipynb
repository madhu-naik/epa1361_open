# %% [markdown]
# # MOEA tutorial
#
# In the previous assignments, we have been using sampling to investigate the uncertainty space and the lever space. However, we can also use optimization algorithms to search through these spaces. Most often, you would use optimization to search through the lever space in order to find promising policies. However, we can also use optimization to search through the uncertainty space in order to find for example a worst case scenario. In this assignment, we are going through the basics of using the optimization functionality of the workbench.
#
# For optimization, the ema_workbench relies on a library called platypus-opt. *platypus-opt* is python package developed by David Hadka (http://platypus.readthedocs.io/en/latest/) for multi-objective optimization. It allows an explicit specification of the problem components (levers, objectives, constraints). The package includes several multi-objective evolutionary algorithms, therefore the users can choose the algorithm they wish to use.
#
# you can use pip to install it:
#
# ```
# pip install platypus-opt
# ```
#
# Start with importing the lake model we have used in previous weeks and connecting it to the workbench. However, we need to make one change: for each outcome of interest we need to specify whether we want to maximize or minimize it, we can use the `kind` kwarg for this. `max_P` should be minimized, while all other outcomes are to be maximized. As a further simplification for this tutorial, we are ignoring the inertia objective. We do this by not setting the `kind` kwarg.

# %%
from lakemodel_function import lake_problem

from ema_workbench import (Model, RealParameter, ScalarOutcome,
                           MultiprocessingEvaluator, ema_logging,
                           Constant)

ema_logging.log_to_stderr(ema_logging.INFO)

#instantiate the model
lake_model = Model('lakeproblem', function=lake_problem)
lake_model.time_horizon = 100 # used to specify the number of timesteps

#specify uncertainties
lake_model.uncertainties = [RealParameter('mean', 0.01, 0.05),
                            RealParameter('stdev', 0.001, 0.005),
                            RealParameter('b', 0.1, 0.45),
                            RealParameter('q', 2.0, 4.5),
                            RealParameter('delta', 0.93, 0.99)]

# set levers, one for each time step
lake_model.levers = [RealParameter(str(i), 0, 0.1) for i in 
                     range(lake_model.time_horizon)] # we use time_horizon here

#specify outcomes 
lake_model.outcomes = [ScalarOutcome('max_P', kind=ScalarOutcome.MINIMIZE),
                       ScalarOutcome('utility', kind=ScalarOutcome.MAXIMIZE),
                       ScalarOutcome('inertia'),
                       ScalarOutcome('reliability', kind=ScalarOutcome.MAXIMIZE)]

lake_model.constantcs = [Constant('alpha', 0.41),
                         Constant('reps', 150)],

# %% [markdown]
# Instead of using `perform_experiments`, we will be using `optimize`. There is several kwargs that we need to provide, so let's go through all:
#
# * **algorithm**; We can specify which algorithm we want to use. The default is $\epsilon$-NSGA2, a state of the art many-objective evolutionary algorithm. We can use any of the other algorithms that come with platypus-opt, or the GenerationalBorg algorithm that comes with the workbench. For now, we won't change this.
# * **nfe**; the number of function evaluations, this is to be determined by analyzing whether the algorithm has converged
# * **searchover**; are we optimizing over the uncertainties or the levers? Most often we will be searching over the levers, so we don't generally need to change this.
# * **reference**; If we are searching over levers, what values should we assume for the uncertainties? Reference allows us to specify this. If searchover is set to levers, reference should be a `Scenario` or None, while if searchover is uncertainties, reference should be a `Policy` or None. In case of a None, the default values of the underlying model are unchanged
# * **constraints**; see below
# * **epsilons**; many state of the art MOEA's rely on a epsilon dominance. Basically, a grid is imposed on the objective space, and per grid cell a singly solution is maintained. The granularity of the grid is specified through the epsilon values. Epsilon should be a list or array with a length equal to the number of outcomes. Below, we will see what the impact is of changing epsilon values.
# * **convergence**; In order to track whether a MOEA has converged to the optimum solutions, we use convergence metrics. The workbench offers epsilon progress and hypervolume as two often used metrics for this. We will explore these below.
#
# let's start with a simple optimization using 5000 nfe, and the 0.25, 0.1, and 0.1 as epsilon values.

# %%
with MultiprocessingEvaluator(lake_model) as evaluator:
    results = evaluator.optimize(nfe=5000, epsilons=[0.25, 0.1, 0.1])
# Out:
# [MainProcess/INFO] pool started
# [MainProcess/INFO] generation 0: 0/5000 nfe
# [MainProcess/INFO] generation 5: 500/5000 nfe
# [MainProcess/INFO] generation 10: 1000/5000 nfe
# [MainProcess/INFO] generation 15: 1500/5000 nfe
# [MainProcess/INFO] generation 20: 2000/5000 nfe
# [MainProcess/INFO] generation 25: 2500/5000 nfe
# [MainProcess/INFO] generation 30: 3000/5000 nfe
# [MainProcess/INFO] generation 35: 3500/5000 nfe
# [MainProcess/INFO] generation 40: 4000/5000 nfe
# [MainProcess/INFO] generation 45: 4500/5000 nfe
# [MainProcess/INFO] optimization completed, found 7 solutions
# [MainProcess/INFO] terminating pool

# %% [markdown]
# Since we are dealing with 3 outcomes of interest, we can still visualize our results in a 3d scatter plot. Alternatively, we can visualize it using a so-called parallel coordinate plot. In a parallel coordinate plot, the dimensions are visualized side by side. A line connecting the dimensions is a single point in the multidimensional space. For more than 3 dimensions, parallel coordiante plots are prefered over 3d scatter plots with additional visual encodings for the other dimensions. The workbench has support for parallel coordinate plots using `ema_workbench.analysis.parcoords`

# %%
from mpl_toolkits.mplot3d import Axes3D  

outcomes = results.loc[:, ['max_P', 'utility', 'reliability']]

fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(outcomes.max_P, outcomes.utility, outcomes.reliability)
ax.set_xlabel('max. P')
ax.set_ylabel('utility')
ax.set_zlabel('reliability')
plt.show()

# %%
from ema_workbench.analysis import parcoords

limits = parcoords.get_limits(outcomes)
axes = parcoords.ParallelAxes(limits)
axes.plot(outcomes)

# we invert this axis so direction of desirability is the same 
axes.invert_axis('max_P') 
plt.show()

# %% [markdown]
# As you can see, the parcoords figure is easier to interpret once you have learned how to read them. We can see a clear tradeoff between max_P and reliability on the one hand, and utility on the other. This is indicated by the crossing lines in between these respective dimensions.
#
# ## Exploring alternative epsilon values
#
# Let's rerun the optimization, but with different epsilon values. Use \[0.5, 0.5, 0.5\]

# %%
with MultiprocessingEvaluator(lake_model) as evaluator:
    results = evaluator.optimize(nfe=5000, epsilons=[0.5, 0.5, 0.5])
# Out:
# [MainProcess/INFO] pool started
# [MainProcess/INFO] generation 0: 0/5000 nfe
# [MainProcess/INFO] generation 5: 500/5000 nfe
# [MainProcess/INFO] generation 10: 1000/5000 nfe
# [MainProcess/INFO] generation 15: 1500/5000 nfe
# [MainProcess/INFO] generation 20: 2000/5000 nfe
# [MainProcess/INFO] generation 25: 2500/5000 nfe
# [MainProcess/INFO] generation 30: 3000/5000 nfe
# [MainProcess/INFO] generation 35: 3500/5000 nfe
# [MainProcess/INFO] generation 40: 4000/5000 nfe
# [MainProcess/INFO] generation 45: 4500/5000 nfe
# [MainProcess/INFO] optimization completed, found 3 solutions
# [MainProcess/INFO] terminating pool

# %%
outcomes = results.loc[:, ['max_P', 'utility', 'reliability']]

limits = parcoords.get_limits(outcomes)
axes = parcoords.ParallelAxes(limits)
axes.plot(outcomes)

# we invert this axis so direction of desirability is the same 
axes.invert_axis('max_P') 
plt.show()

# %% [markdown]
# We see that by making our epsilons higher, we are coursening the grid, and thus are reducing the number of solutions we find. Let's test this by making our epsilons smaller. We now expect to find more solutions. Let's use \[0.125, 0.05, 0.05\]

# %%
with MultiprocessingEvaluator(lake_model) as evaluator:
    results = evaluator.optimize(nfe=5000, epsilons=[0.125, 0.05, 0.05])
# Out:
# [MainProcess/INFO] pool started
# [MainProcess/INFO] generation 0: 0/5000 nfe
# [MainProcess/INFO] generation 5: 500/5000 nfe
# [MainProcess/INFO] generation 10: 1000/5000 nfe
# [MainProcess/INFO] generation 15: 1500/5000 nfe
# [MainProcess/INFO] generation 20: 2000/5000 nfe
# [MainProcess/INFO] generation 25: 2500/5000 nfe
# [MainProcess/INFO] generation 30: 3000/5000 nfe
# [MainProcess/INFO] generation 35: 3500/5000 nfe
# [MainProcess/INFO] generation 40: 4000/5000 nfe
# [MainProcess/INFO] generation 45: 4500/5000 nfe
# [MainProcess/INFO] optimization completed, found 17 solutions
# [MainProcess/INFO] terminating pool

# %%
outcomes = results.loc[:, ['max_P', 'utility', 'reliability']]

limits = parcoords.get_limits(outcomes)
axes = parcoords.ParallelAxes(limits)
axes.plot(outcomes)

# we invert this axis so direction of desirability is the same 
axes.invert_axis('max_P') 
plt.show()

# %% [markdown]
# And as expected, we now have many more solutions. Selecting appropriate epsilon values is tricky. It depends on case specific concerns (with what granularity do we want to find solutions?), as well as runtime considerations. The lower the epsilon values, the more solutions will be maintained in the Pareto set. Given how MOEA's work, this slows down the optimization.
#
# ## Assessing convergence
# Next to selecting appropriate epsilon values, a second key issue is assessing convergence. In the foregoing, we have been running the MOEA for 5000 function evaluations. Is this sufficient? Has the algorithm converged? We have no idea. So, how can we add convergence assessment?
#
# There exist a variety of metrics for assessing convergence of MOEAs. The workbench supports epsilong progress and hypervolume. Epsilon progress measures how often a solution in a new gridcel of the epsilon indexed output space is found. Early on, solutions in new grid cells are found quite frequently. Once the algorithm starts to converge, progress becomes more difficult and thus epsilon progress starts to stabilize. Hypervolume is a measure for how much of the objective space is covered by a given set of non-dominated solutions. THe higher the hypervolume, the larger the space is that is covered by the space. Again, hypervolume will grow quickly early on and starts to stabilize once the algorithm is converging. For a more elaborate description, have a look at [this blog](https://waterprogramming.wordpress.com/tag/hypervolume/).
#
# Since hypervolume requires specifying the objective space within which we want to calculate the volume, we need to know this space. Sometimes it is known a priori. For example in the lake problem, reliability is scalled between 0 and 1. In contrast, the bounds on max_P are not known up front. To help with this, we can introduce a constraint saying that max_P must be below a particulare threshold.

# %%
from ema_workbench.em_framework.optimization import (HyperVolume,
                                                     EpsilonProgress)
from ema_workbench import Constraint

#specify outcomes 
lake_model.outcomes = [ScalarOutcome('max_P', kind=ScalarOutcome.MINIMIZE,
                                     expected_range=(0,5)),
                       ScalarOutcome('utility', kind=ScalarOutcome.MAXIMIZE,
                                     expected_range=(0,2)),
                       ScalarOutcome('inertia'),
                       ScalarOutcome('reliability', kind=ScalarOutcome.MAXIMIZE,
                                     expected_range=(0,1))]

convergence_metrics = [HyperVolume.from_outcomes(lake_model.outcomes),
                       EpsilonProgress()]

constraints = [Constraint("max pollution", outcome_names="max_P",
                          function=lambda x:max(0, x-5))]

# %%
with MultiprocessingEvaluator(lake_model) as evaluator:
    results, convergence = evaluator.optimize(nfe=5000, searchover='levers',
                                    epsilons=[0.125, 0.05, 0.01],
                                    convergence=convergence_metrics,
                                    constraints=constraints)
# Out:
# [MainProcess/INFO] pool started
# [MainProcess/INFO] generation 0: 0/5000 nfe
# [MainProcess/INFO] generation 5: 500/5000 nfe
# [MainProcess/INFO] generation 10: 1000/5000 nfe
# [MainProcess/INFO] generation 15: 1500/5000 nfe
# [MainProcess/INFO] generation 20: 2000/5000 nfe
# [MainProcess/INFO] generation 25: 2500/5000 nfe
# [MainProcess/INFO] generation 30: 3000/5000 nfe
# [MainProcess/INFO] generation 35: 3500/5000 nfe
# [MainProcess/INFO] generation 40: 4000/5000 nfe
# [MainProcess/INFO] generation 45: 4500/5000 nfe
# [MainProcess/INFO] optimization completed, found 24 solutions
# [MainProcess/INFO] terminating pool

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, sharex=True, figsize=(8,4))
ax1.plot(convergence.nfe, convergence.epsilon_progress)
ax1.set_ylabel('$\epsilon$-progress')
ax2.plot(convergence.nfe, convergence.hypervolume)
ax2.set_ylabel('hypervolume')

ax1.set_xlabel('number of function evaluations')
ax2.set_xlabel('number of function evaluations')
plt.show()

# %% [markdown]
# If we look at the above plots, we can see that neither hypervolume, nor $\epsilon$-progress has stablized. 5000 function evaluations is clearly not sufficient. Let's go to another extreme: 100.000. What happens in this case?

# %%
with MultiprocessingEvaluator(lake_model) as evaluator:
    results, convergence = evaluator.optimize(nfe=100000, searchover='levers',
                                    epsilons=[0.125, 0.05, 0.05],
                                    convergence=convergence_metrics,
                                    constraints=constraints,
                                    logging_freq=20)
# Out:
# [MainProcess/INFO] generation 0: 0/100000 nfe
# [MainProcess/INFO] generation 5: 500/100000 nfe
# [MainProcess/INFO] generation 10: 1000/100000 nfe
# [MainProcess/INFO] generation 15: 1500/100000 nfe
# [MainProcess/INFO] generation 20: 2000/100000 nfe
# [MainProcess/INFO] generation 25: 2500/100000 nfe
# [MainProcess/INFO] generation 30: 3000/100000 nfe
# [MainProcess/INFO] generation 35: 3500/100000 nfe
# [MainProcess/INFO] generation 40: 4000/100000 nfe
# [MainProcess/INFO] generation 45: 4500/100000 nfe
# [MainProcess/INFO] generation 50: 5000/100000 nfe
# [MainProcess/INFO] generation 55: 5500/100000 nfe
# [MainProcess/INFO] generation 60: 6000/100000 nfe
# [MainProcess/INFO] generation 65: 6500/100000 nfe
# [MainProcess/INFO] generation 70: 7000/100000 nfe
# [MainProcess/INFO] generation 75: 7500/100000 nfe
# [MainProcess/INFO] generation 80: 8000/100000 nfe
# [MainProcess/INFO] generation 85: 8500/100000 nfe
# [MainProcess/INFO] generation 90: 9000/100000 nfe
# [MainProcess/INFO] generation 95: 9500/100000 nfe
# [MainProcess/INFO] generation 100: 10000/100000 nfe
# [MainProcess/INFO] generation 105: 10342/100000 nfe
# [MainProcess/INFO] generation 110: 10702/100000 nfe
# [MainProcess/INFO] generation 115: 11062/100000 nfe
# [MainProcess/INFO] generation 120: 11422/100000 nfe
# [MainProcess/INFO] generation 125: 11782/100000 nfe
# [MainProcess/INFO] generation 130: 12142/100000 nfe
# [MainProcess/INFO] generation 135: 12502/100000 nfe
# [MainProcess/INFO] generation 140: 12862/100000 nfe
# [MainProcess/INFO] generation 145: 13222/100000 nfe
# [MainProcess/INFO] generation 150: 13582/100000 nfe
# [MainProcess/INFO] generation 155: 13942/100000 nfe
# [MainProcess/INFO] generation 160: 14302/100000 nfe
# [MainProcess/INFO] generation 165: 14662/100000 nfe
# [MainProcess/INFO] generation 170: 15022/100000 nfe
# [MainProcess/INFO] generation 175: 15382/100000 nfe
# [MainProcess/INFO] generation 180: 15742/100000 nfe
# [MainProcess/INFO] generation 185: 16102/100000 nfe
# [MainProcess/INFO] generation 190: 16462/100000 nfe
# [MainProcess/INFO] generation 195: 16822/100000 nfe
# [MainProcess/INFO] generation 200: 17182/100000 nfe
# [MainProcess/INFO] generation 205: 17542/100000 nfe
# [MainProcess/INFO] generation 210: 17902/100000 nfe
# [MainProcess/INFO] generation 215: 18262/100000 nfe
# [MainProcess/INFO] generation 220: 18622/100000 nfe
# [MainProcess/INFO] generation 225: 18982/100000 nfe
# [MainProcess/INFO] generation 230: 19342/100000 nfe
# [MainProcess/INFO] generation 235: 19702/100000 nfe
# [MainProcess/INFO] generation 240: 20062/100000 nfe
# [MainProcess/INFO] generation 245: 20422/100000 nfe
# [MainProcess/INFO] generation 250: 20782/100000 nfe
# [MainProcess/INFO] generation 255: 21142/100000 nfe
# [MainProcess/INFO] generation 260: 21502/100000 nfe
# [MainProcess/INFO] generation 265: 21862/100000 nfe
# [MainProcess/INFO] generation 270: 22222/100000 nfe
# [MainProcess/INFO] generation 275: 22582/100000 nfe
# [MainProcess/INFO] generation 280: 22942/100000 nfe
# [MainProcess/INFO] generation 285: 23302/100000 nfe
# [MainProcess/INFO] generation 290: 23662/100000 nfe
# [MainProcess/INFO] generation 295: 24022/100000 nfe
# [MainProcess/INFO] generation 300: 24382/100000 nfe
# [MainProcess/INFO] generation 305: 24742/100000 nfe
# [MainProcess/INFO] generation 310: 25102/100000 nfe
# [MainProcess/INFO] generation 315: 25462/100000 nfe
# [MainProcess/INFO] generation 320: 25822/100000 nfe
# [MainProcess/INFO] generation 325: 26182/100000 nfe
# [MainProcess/INFO] generation 330: 26542/100000 nfe
# [MainProcess/INFO] generation 335: 26902/100000 nfe
# [MainProcess/INFO] generation 340: 27262/100000 nfe
# [MainProcess/INFO] generation 345: 27622/100000 nfe
# [MainProcess/INFO] generation 350: 27982/100000 nfe
# [MainProcess/INFO] generation 355: 28342/100000 nfe
# [MainProcess/INFO] generation 360: 28702/100000 nfe
# [MainProcess/INFO] generation 365: 29062/100000 nfe
# [MainProcess/INFO] generation 370: 29422/100000 nfe
# [MainProcess/INFO] generation 375: 29782/100000 nfe
# [MainProcess/INFO] generation 380: 30142/100000 nfe
# [MainProcess/INFO] generation 385: 30502/100000 nfe
# [MainProcess/INFO] generation 390: 30862/100000 nfe
# [MainProcess/INFO] generation 395: 31222/100000 nfe
# [MainProcess/INFO] generation 400: 31582/100000 nfe
# [MainProcess/INFO] generation 405: 31942/100000 nfe
# [MainProcess/INFO] generation 410: 32302/100000 nfe
# [MainProcess/INFO] generation 415: 32662/100000 nfe
# [MainProcess/INFO] generation 420: 33022/100000 nfe
# [MainProcess/INFO] generation 425: 33382/100000 nfe
# [MainProcess/INFO] generation 430: 33742/100000 nfe
# [MainProcess/INFO] generation 435: 34102/100000 nfe
# [MainProcess/INFO] generation 440: 34462/100000 nfe
# [MainProcess/INFO] generation 445: 34822/100000 nfe
# [MainProcess/INFO] generation 450: 35182/100000 nfe
# [MainProcess/INFO] generation 455: 35542/100000 nfe
# [MainProcess/INFO] generation 460: 35902/100000 nfe
# [MainProcess/INFO] generation 465: 36262/100000 nfe
# [MainProcess/INFO] generation 470: 36622/100000 nfe
# [MainProcess/INFO] generation 475: 36982/100000 nfe
# [MainProcess/INFO] generation 480: 37342/100000 nfe
# [MainProcess/INFO] generation 485: 37702/100000 nfe
# [MainProcess/INFO] generation 490: 38062/100000 nfe
# [MainProcess/INFO] generation 495: 38422/100000 nfe
# [MainProcess/INFO] generation 500: 38782/100000 nfe
# [MainProcess/INFO] generation 505: 39142/100000 nfe
# [MainProcess/INFO] generation 510: 39502/100000 nfe
# [MainProcess/INFO] generation 515: 39862/100000 nfe
# [MainProcess/INFO] generation 520: 40222/100000 nfe
# [MainProcess/INFO] generation 525: 40582/100000 nfe
# [MainProcess/INFO] generation 530: 40942/100000 nfe
# [MainProcess/INFO] generation 535: 41302/100000 nfe
# [MainProcess/INFO] generation 540: 41662/100000 nfe
# [MainProcess/INFO] generation 545: 42022/100000 nfe
# [MainProcess/INFO] generation 550: 42382/100000 nfe
# [MainProcess/INFO] generation 555: 42742/100000 nfe
# [MainProcess/INFO] generation 560: 43102/100000 nfe
# [MainProcess/INFO] generation 565: 43462/100000 nfe
# [MainProcess/INFO] generation 570: 43822/100000 nfe
# [MainProcess/INFO] generation 575: 44182/100000 nfe
# [MainProcess/INFO] generation 580: 44542/100000 nfe
# [MainProcess/INFO] generation 585: 44902/100000 nfe
# [MainProcess/INFO] generation 590: 45262/100000 nfe
# [MainProcess/INFO] generation 595: 45622/100000 nfe
# [MainProcess/INFO] generation 600: 45982/100000 nfe
# [MainProcess/INFO] generation 605: 46342/100000 nfe
# [MainProcess/INFO] generation 610: 46702/100000 nfe
# [MainProcess/INFO] generation 615: 47062/100000 nfe
# [MainProcess/INFO] generation 620: 47422/100000 nfe
# [MainProcess/INFO] generation 625: 47782/100000 nfe
# [MainProcess/INFO] generation 630: 48142/100000 nfe
# [MainProcess/INFO] generation 635: 48502/100000 nfe
# [MainProcess/INFO] generation 640: 48862/100000 nfe
# [MainProcess/INFO] generation 645: 49222/100000 nfe
# [MainProcess/INFO] generation 650: 49582/100000 nfe
# [MainProcess/INFO] generation 655: 49942/100000 nfe
# [MainProcess/INFO] generation 660: 50302/100000 nfe
# [MainProcess/INFO] generation 665: 50662/100000 nfe
# [MainProcess/INFO] generation 670: 51022/100000 nfe
# [MainProcess/INFO] generation 675: 51382/100000 nfe
# [MainProcess/INFO] generation 680: 51742/100000 nfe
# [MainProcess/INFO] generation 685: 52102/100000 nfe
# [MainProcess/INFO] generation 690: 52462/100000 nfe
# [MainProcess/INFO] generation 695: 52822/100000 nfe
# [MainProcess/INFO] generation 700: 53182/100000 nfe
# [MainProcess/INFO] generation 705: 53542/100000 nfe
# [MainProcess/INFO] generation 710: 53902/100000 nfe
# [MainProcess/INFO] generation 715: 54262/100000 nfe
# [MainProcess/INFO] generation 720: 54622/100000 nfe
# [MainProcess/INFO] generation 725: 54982/100000 nfe
# [MainProcess/INFO] generation 730: 55342/100000 nfe
# [MainProcess/INFO] generation 735: 55702/100000 nfe
# [MainProcess/INFO] generation 740: 56062/100000 nfe
# [MainProcess/INFO] generation 745: 56422/100000 nfe
# [MainProcess/INFO] generation 750: 56782/100000 nfe
# [MainProcess/INFO] generation 755: 57142/100000 nfe
# [MainProcess/INFO] generation 760: 57502/100000 nfe
# [MainProcess/INFO] generation 765: 57862/100000 nfe
# [MainProcess/INFO] generation 770: 58222/100000 nfe
# [MainProcess/INFO] generation 775: 58582/100000 nfe
# [MainProcess/INFO] generation 780: 58942/100000 nfe
# [MainProcess/INFO] generation 785: 59302/100000 nfe
# [MainProcess/INFO] generation 790: 59662/100000 nfe
# [MainProcess/INFO] generation 795: 60022/100000 nfe
# [MainProcess/INFO] generation 800: 60382/100000 nfe
# [MainProcess/INFO] generation 805: 60742/100000 nfe
# [MainProcess/INFO] generation 810: 61102/100000 nfe
# [MainProcess/INFO] generation 815: 61462/100000 nfe
# [MainProcess/INFO] generation 820: 61822/100000 nfe
# [MainProcess/INFO] generation 825: 62182/100000 nfe
# [MainProcess/INFO] generation 830: 62542/100000 nfe
# [MainProcess/INFO] generation 835: 62902/100000 nfe
# [MainProcess/INFO] generation 840: 63262/100000 nfe
# [MainProcess/INFO] generation 845: 63622/100000 nfe
# [MainProcess/INFO] generation 850: 63982/100000 nfe
# [MainProcess/INFO] generation 855: 64342/100000 nfe
# [MainProcess/INFO] generation 860: 64702/100000 nfe
# [MainProcess/INFO] generation 865: 65062/100000 nfe
# [MainProcess/INFO] generation 870: 65422/100000 nfe
# [MainProcess/INFO] generation 875: 65782/100000 nfe
# [MainProcess/INFO] generation 880: 66142/100000 nfe
# [MainProcess/INFO] generation 885: 66502/100000 nfe
# [MainProcess/INFO] generation 890: 66862/100000 nfe
# [MainProcess/INFO] generation 895: 67222/100000 nfe
# [MainProcess/INFO] generation 900: 67582/100000 nfe
# [MainProcess/INFO] generation 905: 67942/100000 nfe
# [MainProcess/INFO] generation 910: 68302/100000 nfe
# [MainProcess/INFO] generation 915: 68662/100000 nfe
# [MainProcess/INFO] generation 920: 69022/100000 nfe
# [MainProcess/INFO] generation 925: 69382/100000 nfe
# [MainProcess/INFO] generation 930: 69742/100000 nfe
# [MainProcess/INFO] generation 935: 70102/100000 nfe
# [MainProcess/INFO] generation 940: 70462/100000 nfe
# [MainProcess/INFO] generation 945: 70822/100000 nfe
# [MainProcess/INFO] generation 950: 71182/100000 nfe
# [MainProcess/INFO] generation 955: 71542/100000 nfe
# [MainProcess/INFO] generation 960: 71902/100000 nfe
# [MainProcess/INFO] generation 965: 72262/100000 nfe
# [MainProcess/INFO] generation 970: 72622/100000 nfe
# [MainProcess/INFO] generation 975: 72982/100000 nfe
# [MainProcess/INFO] generation 980: 73342/100000 nfe
# [MainProcess/INFO] generation 985: 73702/100000 nfe
# [MainProcess/INFO] generation 990: 74062/100000 nfe
# [MainProcess/INFO] generation 995: 74422/100000 nfe
# [MainProcess/INFO] generation 1000: 74782/100000 nfe
# [MainProcess/INFO] generation 1005: 75142/100000 nfe
# [MainProcess/INFO] generation 1010: 75502/100000 nfe
# [MainProcess/INFO] generation 1015: 75862/100000 nfe
# [MainProcess/INFO] generation 1020: 76222/100000 nfe
# [MainProcess/INFO] generation 1025: 76582/100000 nfe
# [MainProcess/INFO] generation 1030: 76942/100000 nfe
# [MainProcess/INFO] generation 1035: 77302/100000 nfe
# [MainProcess/INFO] generation 1040: 77662/100000 nfe
# [MainProcess/INFO] generation 1045: 78022/100000 nfe
# [MainProcess/INFO] generation 1050: 78382/100000 nfe
# [MainProcess/INFO] generation 1055: 78742/100000 nfe
# [MainProcess/INFO] generation 1060: 79102/100000 nfe
# [MainProcess/INFO] generation 1065: 79462/100000 nfe
# [MainProcess/INFO] generation 1070: 79822/100000 nfe
# [MainProcess/INFO] generation 1075: 80182/100000 nfe
# [MainProcess/INFO] generation 1080: 80542/100000 nfe
# [MainProcess/INFO] generation 1085: 80902/100000 nfe
# [MainProcess/INFO] generation 1090: 81262/100000 nfe
# [MainProcess/INFO] generation 1095: 81622/100000 nfe
# [MainProcess/INFO] generation 1100: 81982/100000 nfe
# [MainProcess/INFO] generation 1105: 82346/100000 nfe
# [MainProcess/INFO] generation 1110: 82736/100000 nfe
# [MainProcess/INFO] generation 1115: 83126/100000 nfe
# [MainProcess/INFO] generation 1120: 83516/100000 nfe
# [MainProcess/INFO] generation 1125: 83906/100000 nfe
# [MainProcess/INFO] generation 1130: 84296/100000 nfe
# [MainProcess/INFO] generation 1135: 84686/100000 nfe
# [MainProcess/INFO] generation 1140: 85076/100000 nfe
# [MainProcess/INFO] generation 1145: 85466/100000 nfe
# [MainProcess/INFO] generation 1150: 85856/100000 nfe
# [MainProcess/INFO] generation 1155: 86246/100000 nfe
# [MainProcess/INFO] generation 1160: 86636/100000 nfe
# [MainProcess/INFO] generation 1165: 87026/100000 nfe
# [MainProcess/INFO] generation 1170: 87416/100000 nfe
# [MainProcess/INFO] generation 1175: 87806/100000 nfe
# [MainProcess/INFO] generation 1180: 88196/100000 nfe
# [MainProcess/INFO] generation 1185: 88586/100000 nfe
# [MainProcess/INFO] generation 1190: 88976/100000 nfe
# [MainProcess/INFO] generation 1195: 89366/100000 nfe
# [MainProcess/INFO] generation 1200: 89756/100000 nfe
# [MainProcess/INFO] generation 1205: 90146/100000 nfe
# [MainProcess/INFO] generation 1210: 90536/100000 nfe
# [MainProcess/INFO] generation 1215: 90926/100000 nfe
# [MainProcess/INFO] generation 1220: 91316/100000 nfe
# [MainProcess/INFO] generation 1225: 91706/100000 nfe
# [MainProcess/INFO] generation 1230: 92096/100000 nfe
# [MainProcess/INFO] generation 1235: 92486/100000 nfe
# [MainProcess/INFO] generation 1240: 92876/100000 nfe
# [MainProcess/INFO] generation 1245: 93266/100000 nfe
# [MainProcess/INFO] generation 1250: 93656/100000 nfe
# [MainProcess/INFO] generation 1255: 94046/100000 nfe
# [MainProcess/INFO] generation 1260: 94436/100000 nfe
# [MainProcess/INFO] generation 1265: 94826/100000 nfe
# [MainProcess/INFO] generation 1270: 95216/100000 nfe
# [MainProcess/INFO] generation 1275: 95606/100000 nfe
# [MainProcess/INFO] generation 1280: 95996/100000 nfe
# [MainProcess/INFO] generation 1285: 96386/100000 nfe
# [MainProcess/INFO] generation 1290: 96776/100000 nfe
# [MainProcess/INFO] generation 1295: 97166/100000 nfe
# [MainProcess/INFO] generation 1300: 97556/100000 nfe
# [MainProcess/INFO] generation 1305: 97946/100000 nfe
# [MainProcess/INFO] generation 1310: 98336/100000 nfe
# [MainProcess/INFO] generation 1315: 98726/100000 nfe
# [MainProcess/INFO] generation 1320: 99116/100000 nfe
# [MainProcess/INFO] generation 1325: 99506/100000 nfe
# [MainProcess/INFO] generation 1330: 99896/100000 nfe
# [MainProcess/INFO] optimization completed, found 19 solutions

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, sharex=True, figsize=(8,4))
ax1.plot(convergence.nfe, convergence.epsilon_progress)
ax1.set_ylabel('$\epsilon$-progress')
ax2.plot(convergence.nfe, convergence.hypervolume)
ax2.set_ylabel('hypervolume')

ax1.set_xlabel('number of function evaluations')
ax2.set_xlabel('number of function evaluations')
plt.show()

# %% [markdown]
# The runtime of this analysis has been substantial. Still, looking at the convergen graphs, hypervolume has more or less stablized, while $\epsilon$-progress only starts to stablize. This could be an argument for running the algorithm even longer (say 250.000 nfe). Establising the number of NFE is generally a form of trial and error.

# %% [markdown]
# # The role of stochasticity
# MOEAs use stochastics in crossover and mutation. Thus, the specific set of results will vary from one run of the algorithm to the next. Analogous to how you deal with stochasticitiy in discrete event models, it is best practice to run an MOEA multiple times using a different random seed. Next, you would combine the results from the different runs into a combined pareto approximate set.

# %%
all_results = []

with MultiprocessingEvaluator(lake_model) as evaluator:
    for rep in range(5):
        # 5000 runs is clearly way to low, givent he convergence 
        # analysis above. this is only for demonstration purposes
        results = evaluator.optimize(nfe=5000, searchover='levers',
                                     epsilons=[0.125, 0.05, 0.05],
                                     constraints=constraints)
        all_results.append(results)
# Out:
# [MainProcess/INFO] generation 0: 0/5000 nfe
# [MainProcess/INFO] generation 5: 500/5000 nfe
# [MainProcess/INFO] generation 10: 1000/5000 nfe
# [MainProcess/INFO] generation 15: 1500/5000 nfe
# [MainProcess/INFO] generation 20: 2000/5000 nfe
# [MainProcess/INFO] generation 25: 2500/5000 nfe
# [MainProcess/INFO] generation 30: 3000/5000 nfe
# [MainProcess/INFO] generation 35: 3500/5000 nfe
# [MainProcess/INFO] generation 40: 4000/5000 nfe
# [MainProcess/INFO] generation 45: 4500/5000 nfe
# [MainProcess/INFO] optimization completed, found 16 solutions
# [MainProcess/INFO] generation 0: 0/5000 nfe
# [MainProcess/INFO] generation 5: 500/5000 nfe
# [MainProcess/INFO] generation 10: 1000/5000 nfe
# [MainProcess/INFO] generation 15: 1500/5000 nfe
# [MainProcess/INFO] generation 20: 2000/5000 nfe
# [MainProcess/INFO] generation 25: 2500/5000 nfe
# [MainProcess/INFO] generation 30: 3000/5000 nfe
# [MainProcess/INFO] generation 35: 3500/5000 nfe
# [MainProcess/INFO] generation 40: 4000/5000 nfe
# [MainProcess/INFO] generation 45: 4500/5000 nfe
# [MainProcess/INFO] optimization completed, found 16 solutions
# [MainProcess/INFO] generation 0: 0/5000 nfe
# [MainProcess/INFO] generation 5: 500/5000 nfe
# [MainProcess/INFO] generation 10: 1000/5000 nfe
# [MainProcess/INFO] generation 15: 1500/5000 nfe
# [MainProcess/INFO] generation 20: 2000/5000 nfe
# [MainProcess/INFO] generation 25: 2500/5000 nfe
# [MainProcess/INFO] generation 30: 3000/5000 nfe
# [MainProcess/INFO] generation 35: 3500/5000 nfe
# [MainProcess/INFO] generation 40: 4000/5000 nfe
# [MainProcess/INFO] generation 45: 4500/5000 nfe
# [MainProcess/INFO] optimization completed, found 14 solutions
# [MainProcess/INFO] generation 0: 0/5000 nfe
# [MainProcess/INFO] generation 5: 500/5000 nfe
# [MainProcess/INFO] generation 10: 1000/5000 nfe
# [MainProcess/INFO] generation 15: 1500/5000 nfe
# [MainProcess/INFO] generation 20: 2000/5000 nfe
# [MainProcess/INFO] generation 25: 2500/5000 nfe
# [MainProcess/INFO] generation 30: 3000/5000 nfe
# [MainProcess/INFO] generation 35: 3500/5000 nfe
# [MainProcess/INFO] generation 40: 4000/5000 nfe
# [MainProcess/INFO] generation 45: 4500/5000 nfe
# [MainProcess/INFO] optimization completed, found 15 solutions
# [MainProcess/INFO] generation 0: 0/5000 nfe
# [MainProcess/INFO] generation 5: 500/5000 nfe
# [MainProcess/INFO] generation 10: 1000/5000 nfe
# [MainProcess/INFO] generation 15: 1500/5000 nfe
# [MainProcess/INFO] generation 20: 2000/5000 nfe
# [MainProcess/INFO] generation 25: 2500/5000 nfe
# [MainProcess/INFO] generation 30: 3000/5000 nfe
# [MainProcess/INFO] generation 35: 3500/5000 nfe
# [MainProcess/INFO] generation 40: 4000/5000 nfe
# [MainProcess/INFO] generation 45: 4500/5000 nfe
# [MainProcess/INFO] optimization completed, found 18 solutions

# %%
limits = pd.DataFrame([[0,0,0],[5,2,1]], columns=['max_P', 'utility', 'reliability'])
axes = parcoords.ParallelAxes(limits)

for i, (result, color) in enumerate(zip(all_results, sns.color_palette())):
    outcomes = result.loc[:, ['max_P', 'utility', 'reliability']]
    axes.plot(outcomes, color=color, label='results {}'.format(i))

# we invert this axis so direction of desirability is the same  
axes.invert_axis('max_P') 
axes.legend()
plt.show()
# Out:
# /Users/jhkwakkel/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py:323: DataConversionWarning: Data with input dtype int64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)

# %% [markdown]
# # Using an alternative optimization algorithm
#
# In this exercise, I recommend to use Platypus with the ε-NSGAII algorithm, since it is shown to outperform many MOEA’s. For other algortihms, see the documentation of Platypus. For a comparison of them, you can have a look at [Reed et al (2013)](http://dx.doi.org/10.1016/j.advwatres.2012.01.005).

# %%
from ema_workbench.em_framework.optimization import GenerationalBorg

with MultiprocessingEvaluator(lake_model) as evaluator:
    results, convergence = evaluator.optimize(nfe=50000, searchover='levers',
                                    epsilons=[0.125, 0.05, 0.05],
                                    convergence=convergence_metrics,
                                    constraints=constraints,
                                    algorithm=GenerationalBorg)
# Out:
# [MainProcess/INFO] pool started
# [MainProcess/INFO] generation 0: 0/50000 nfe
# [MainProcess/INFO] generation 5: 504/50000 nfe
# [MainProcess/INFO] generation 10: 1005/50000 nfe
# [MainProcess/INFO] generation 15: 1507/50000 nfe
# [MainProcess/INFO] generation 20: 2009/50000 nfe
# [MainProcess/INFO] generation 25: 2511/50000 nfe
# [MainProcess/INFO] generation 30: 3014/50000 nfe
# [MainProcess/INFO] generation 35: 3518/50000 nfe
# [MainProcess/INFO] generation 40: 4020/50000 nfe
# [MainProcess/INFO] generation 45: 4523/50000 nfe
# [MainProcess/INFO] generation 50: 5026/50000 nfe
# [MainProcess/INFO] generation 55: 5528/50000 nfe
# [MainProcess/INFO] generation 60: 6030/50000 nfe
# [MainProcess/INFO] generation 65: 6533/50000 nfe
# [MainProcess/INFO] generation 70: 7035/50000 nfe
# [MainProcess/INFO] generation 75: 7537/50000 nfe
# [MainProcess/INFO] generation 80: 8039/50000 nfe
# [MainProcess/INFO] generation 85: 8541/50000 nfe
# [MainProcess/INFO] generation 90: 9044/50000 nfe
# [MainProcess/INFO] generation 95: 9547/50000 nfe
# [MainProcess/INFO] generation 100: 10047/50000 nfe
# [MainProcess/INFO] generation 105: 10375/50000 nfe
# [MainProcess/INFO] generation 110: 10724/50000 nfe
# [MainProcess/INFO] generation 115: 11072/50000 nfe
# [MainProcess/INFO] generation 120: 11418/50000 nfe
# [MainProcess/INFO] generation 125: 11765/50000 nfe
# [MainProcess/INFO] generation 130: 12112/50000 nfe
# [MainProcess/INFO] generation 135: 12460/50000 nfe
# [MainProcess/INFO] generation 140: 12808/50000 nfe
# [MainProcess/INFO] generation 145: 13155/50000 nfe
# [MainProcess/INFO] generation 150: 13502/50000 nfe
# [MainProcess/INFO] generation 155: 13848/50000 nfe
# [MainProcess/INFO] generation 160: 14194/50000 nfe
# [MainProcess/INFO] generation 165: 14542/50000 nfe
# [MainProcess/INFO] generation 170: 14888/50000 nfe
# [MainProcess/INFO] generation 175: 15236/50000 nfe
# [MainProcess/INFO] generation 180: 15583/50000 nfe
# [MainProcess/INFO] generation 185: 15932/50000 nfe
# [MainProcess/INFO] generation 190: 16278/50000 nfe
# [MainProcess/INFO] generation 195: 16626/50000 nfe
# [MainProcess/INFO] generation 200: 16974/50000 nfe
# [MainProcess/INFO] generation 205: 17321/50000 nfe
# [MainProcess/INFO] generation 210: 17670/50000 nfe
# [MainProcess/INFO] generation 215: 18016/50000 nfe
# [MainProcess/INFO] generation 220: 18362/50000 nfe
# [MainProcess/INFO] generation 225: 18710/50000 nfe
# [MainProcess/INFO] generation 230: 19056/50000 nfe
# [MainProcess/INFO] generation 235: 19402/50000 nfe
# [MainProcess/INFO] generation 240: 19750/50000 nfe
# [MainProcess/INFO] generation 245: 20096/50000 nfe
# [MainProcess/INFO] generation 250: 20445/50000 nfe
# [MainProcess/INFO] generation 255: 20790/50000 nfe
# [MainProcess/INFO] generation 260: 21140/50000 nfe
# [MainProcess/INFO] generation 265: 21487/50000 nfe
# [MainProcess/INFO] generation 270: 21835/50000 nfe
# [MainProcess/INFO] generation 275: 22184/50000 nfe
# [MainProcess/INFO] generation 280: 22529/50000 nfe
# [MainProcess/INFO] generation 285: 22879/50000 nfe
# [MainProcess/INFO] generation 290: 23227/50000 nfe
# [MainProcess/INFO] generation 295: 23574/50000 nfe
# [MainProcess/INFO] generation 300: 23920/50000 nfe
# [MainProcess/INFO] generation 305: 24267/50000 nfe
# [MainProcess/INFO] generation 310: 24616/50000 nfe
# [MainProcess/INFO] generation 315: 24964/50000 nfe
# [MainProcess/INFO] generation 320: 25310/50000 nfe
# [MainProcess/INFO] generation 325: 25656/50000 nfe
# [MainProcess/INFO] generation 330: 26001/50000 nfe
# [MainProcess/INFO] generation 335: 26348/50000 nfe
# [MainProcess/INFO] generation 340: 26696/50000 nfe
# [MainProcess/INFO] generation 345: 27045/50000 nfe
# [MainProcess/INFO] generation 350: 27392/50000 nfe
# [MainProcess/INFO] generation 355: 27742/50000 nfe
# [MainProcess/INFO] generation 360: 28090/50000 nfe
# [MainProcess/INFO] generation 365: 28437/50000 nfe
# [MainProcess/INFO] generation 370: 28783/50000 nfe
# [MainProcess/INFO] generation 375: 29129/50000 nfe
# [MainProcess/INFO] generation 380: 29477/50000 nfe
# [MainProcess/INFO] generation 385: 29823/50000 nfe
# [MainProcess/INFO] generation 390: 30172/50000 nfe
# [MainProcess/INFO] generation 395: 30520/50000 nfe
# [MainProcess/INFO] generation 400: 30868/50000 nfe
# [MainProcess/INFO] generation 405: 31217/50000 nfe
# [MainProcess/INFO] generation 410: 31563/50000 nfe
# [MainProcess/INFO] generation 415: 31911/50000 nfe
# [MainProcess/INFO] generation 420: 32258/50000 nfe
# [MainProcess/INFO] generation 425: 32604/50000 nfe
# [MainProcess/INFO] generation 430: 32952/50000 nfe
# [MainProcess/INFO] generation 435: 33301/50000 nfe
# [MainProcess/INFO] generation 440: 33648/50000 nfe
# [MainProcess/INFO] generation 445: 33996/50000 nfe
# [MainProcess/INFO] generation 450: 34342/50000 nfe
# [MainProcess/INFO] generation 455: 34691/50000 nfe
# [MainProcess/INFO] generation 460: 35038/50000 nfe
# [MainProcess/INFO] generation 465: 35384/50000 nfe
# [MainProcess/INFO] generation 470: 35732/50000 nfe
# [MainProcess/INFO] generation 475: 36078/50000 nfe
# [MainProcess/INFO] generation 480: 36425/50000 nfe
# [MainProcess/INFO] generation 485: 36771/50000 nfe
# [MainProcess/INFO] generation 490: 37119/50000 nfe
# [MainProcess/INFO] generation 495: 37467/50000 nfe
# [MainProcess/INFO] generation 500: 37815/50000 nfe
# [MainProcess/INFO] generation 505: 38162/50000 nfe
# [MainProcess/INFO] generation 510: 38509/50000 nfe
# [MainProcess/INFO] generation 515: 38857/50000 nfe
# [MainProcess/INFO] generation 520: 39205/50000 nfe
# [MainProcess/INFO] generation 525: 39552/50000 nfe
# [MainProcess/INFO] generation 530: 39899/50000 nfe
# [MainProcess/INFO] generation 535: 40247/50000 nfe
# [MainProcess/INFO] generation 540: 40594/50000 nfe
# [MainProcess/INFO] generation 545: 40940/50000 nfe
# [MainProcess/INFO] generation 550: 41286/50000 nfe
# [MainProcess/INFO] generation 555: 41633/50000 nfe
# [MainProcess/INFO] generation 560: 41981/50000 nfe
# [MainProcess/INFO] generation 565: 42329/50000 nfe
# [MainProcess/INFO] generation 570: 42677/50000 nfe
# [MainProcess/INFO] generation 575: 43023/50000 nfe
# [MainProcess/INFO] generation 580: 43370/50000 nfe
# [MainProcess/INFO] generation 585: 43717/50000 nfe
# [MainProcess/INFO] generation 590: 44062/50000 nfe
# [MainProcess/INFO] generation 595: 44410/50000 nfe
# [MainProcess/INFO] generation 600: 44757/50000 nfe
# [MainProcess/INFO] generation 605: 45104/50000 nfe
# [MainProcess/INFO] generation 610: 45452/50000 nfe
# [MainProcess/INFO] generation 615: 45799/50000 nfe
# [MainProcess/INFO] generation 620: 46148/50000 nfe
# [MainProcess/INFO] generation 625: 46496/50000 nfe
# [MainProcess/INFO] generation 630: 46843/50000 nfe
# [MainProcess/INFO] generation 635: 47190/50000 nfe
# [MainProcess/INFO] generation 640: 47537/50000 nfe
# [MainProcess/INFO] generation 645: 47883/50000 nfe
# [MainProcess/INFO] generation 650: 48231/50000 nfe
# [MainProcess/INFO] generation 655: 48578/50000 nfe
# [MainProcess/INFO] generation 660: 48924/50000 nfe
# [MainProcess/INFO] generation 665: 49271/50000 nfe
# [MainProcess/INFO] generation 670: 49620/50000 nfe
# [MainProcess/INFO] generation 675: 49967/50000 nfe
# [MainProcess/INFO] optimization completed, found 19 solutions
# [MainProcess/INFO] terminating pool

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, sharex=True, figsize=(8,4))
ax1.plot(convergence.nfe, convergence.epsilon_progress)
ax1.set_ylabel('$\epsilon$-progress')
ax2.plot(convergence.nfe, convergence.hypervolume)
ax2.set_ylabel('hypervolume')

ax1.set_xlabel('number of function evaluations')
ax2.set_xlabel('number of function evaluations')
plt.show()
